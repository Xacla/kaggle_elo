# %%
import pandas as pd
import os

path = os.getcwd()
print(path)  

df = pd.read_csv('../../new_merchant_transactions.csv')
df[0:5]
# Out:
# /Users/owner/Desktop/kagle_elo/input/features/features_program
#   authorized_flag          card_id  city_id category_1  installments  \
# 0               Y  C_ID_415bb3a509      107          N             1
# 1               Y  C_ID_415bb3a509      140          N             1
# 2               Y  C_ID_415bb3a509      330          N             1
# 3               Y  C_ID_415bb3a509       -1          Y             1
# 4               Y  C_ID_ef55cf8d4b       -1          Y             1
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          B                   307  M_ID_b0c793002c          1
# 1          B                   307  M_ID_88920c89e8          1
# 2          B                   507  M_ID_ad5237ef6b          2
# 3          B                   661  M_ID_9e84cda3b1          1
# 4          B                   166  M_ID_3c86fa3831          1
#
#    purchase_amount        purchase_date  category_2  state_id  subsector_id
# ...

# %%
for i in ['category_1','authorized_flag']:
   df[i]=df[i].map({'Y':1,'N':0,' ':-1})

# %%
df['category_3']=df['category_3'].map({'A':1,'B':2,'C':3,'D':4,'E':5})

# %%
df[0:5]
# Out:
#    authorized_flag          card_id  city_id  category_1  installments  \
# 0                1  C_ID_415bb3a509      107           0             1
# 1                1  C_ID_415bb3a509      140           0             1
# 2                1  C_ID_415bb3a509      330           0             1
# 3                1  C_ID_415bb3a509       -1           1             1
# 4                1  C_ID_ef55cf8d4b       -1           1             1
#
#    category_3  merchant_category_id      merchant_id  month_lag  \
# 0         2.0                   307  M_ID_b0c793002c          1
# 1         2.0                   307  M_ID_88920c89e8          1
# 2         2.0                   507  M_ID_ad5237ef6b          2
# 3         2.0                   661  M_ID_9e84cda3b1          1
# 4         2.0                   166  M_ID_3c86fa3831          1
#
#    purchase_amount        purchase_date  category_2  state_id  subsector_id
# 0        -0.557574  2018-03-11 14:57:36         1.0         9            19
# ...

# %%
df.to_csv("../../nmt_replace.csv")

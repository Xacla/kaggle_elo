# %%
import pandas as pd
import umap
import matplotlib.pyplot as plt
 
input_path='/Users/tomita/Desktop/kaggle_elo/'
 #dataの前処理
train=pd.read_csv(input_path+'input/train.csv')
datas=pd.read_csv(input_path+'input/merchants.csv')
rank_list=pd.read_csv(input_path+'input/features/rank.csv')

# %%
datas.head()
# Out:
#        merchant_id  merchant_group_id  merchant_category_id  subsector_id  \
# 0  M_ID_838061e48c               8353                   792             9
# 1  M_ID_9339d880ad               3184                   840            20
# 2  M_ID_e726bbae1e                447                   690             1
# 3  M_ID_a70e9c5f81               5026                   792             9
# 4  M_ID_64456c37ce               2228                   222            21
#
#    numerical_1  numerical_2 category_1 most_recent_sales_range  \
# 0    -0.057471    -0.057471          N                       E
# 1    -0.057471    -0.057471          N                       E
# 2    -0.057471    -0.057471          N                       E
# 3    -0.057471    -0.057471          Y                       E
# 4    -0.057471    -0.057471          Y                       E
#
#   most_recent_purchases_range  avg_sales_lag3     ...      avg_sales_lag6  \
# ...

# %%
rank_list.head()
# Out:
#   rank  number
# 0    A       4
# 1    B       3
# 2    C       2
# 3    D       1
# 4    E       0

# %% [markdown]
# category_1,most_recent_sales_range,most_recent_purchases_range,category_4について処理をしていく

# %%
print(datas.iloc[0,7])
copy_iloc=datas.iloc[0,7]
# Out:
# E

# %%
hoge=rank_list.reset_index().query(' rank== @copy_iloc').index[0]
rank_list.iloc[rank_list.reset_index().query(' rank== @copy_iloc').index[0],1]
# Out:
# 0

# %%
for i in range(datas.shape[0]):
    aa=datas.columns.get_loc('most_recent_sales_range')
    copy_iloc=datas.iloc[i,aa]
    datas.iloc[i,aa]=rank_list.iloc[rank_list.reset_index().query(' rank== @copy_iloc').index[0],1]
    aa=datas.columns.get_loc('most_recent_purchases_range')
    copy_iloc=datas.iloc[i,aa]
    datas.iloc[i,aa]=rank_list.iloc[rank_list.reset_index().query(' rank== @copy_iloc').index[0],1]
    
    
drop_columns=['merchant_id']
datas.drop(drop_columns,axis=1)


#print(datas.loc(0))
